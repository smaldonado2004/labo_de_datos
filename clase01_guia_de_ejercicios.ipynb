# %% [markdown]
# <a href="https://colab.research.google.com/github/smaldonado2004/labo_de_datos/blob/main/clase01_guia_de_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a) Ingresar los siguientes comandos en una sola celda y observar el resultado al apretar
# SHIFT-ENTER. ¿Que sucede? ¿Por que?

# %%
2 + 2
3 * 5 #solo hace el ultimo calculo
# Out:
# 15

# %%
print (2 + 2)
print (3 * 5) #se ordena hacer ambos calculos
# Out:
# 4
# 15

# %% [markdown]
# (c) Orden de ejecucion. Ejecutar el contenido de esta celda dos veces. Cambia la salida?

# %%
a = 5
a = a + 1
print ( a ) #no pq defino a = 5
# Out:
# 6

# %% [markdown]
# Luego de ejecutar la celda anterior, ejecutar el contenido de esta celda dos veces. ¿Cambia
# la salida en cada caso? ¿Por que?

# %%
a = a + 1
print ( a ) #primero sale 7 y luego 8 pq a no tiene un punto de partida fijo
# Out:
# 8

# %% [markdown]
# 4. Antes de probar en la consola, piense que van a dar estas operaciones.

# %%
a , b , c = 3 , 4 , 2
#OJO: esta forma de asignar dice a= 3, b=4 y c=2
print("op1: ", a > b)
print("op2: ",a <= b)
print("op3: ",a != b)
print("op4: ",a == b)
print("op5: ",not( a > b ) )
print("op6: ", (( c > a ) or (10 * c > b ) ) and not ( b / a > c ) )
                # F or ( 10*2 = 20 > 4 TRUE) and not (False)
                # (F or T) and T   ==> T and T
# Out:
# op1:  False
# op2:  True
# op3:  True
# op4:  False
# op5:  True
# op6:  True

# %% [markdown]
# 5. Bonus: Abra la documentacion de Python y lea sobre tuplas.
# 6. **Listas.** Las listas permiten guardar **valores de distintos tipos** en forma ordenada y **acceder a
# los distintos elementos por su ındice**, comenzando desde 0.

# %%
s = [1 , 2 , 3.0 , " hola ", 7 + 3]
s , s [0] , s [1] , s [ -1]
# Out:
# ([1, 2, 3.0, ' hola ', 10], 1, 2, 10)

# %% [markdown]
# ACAAAAAAAAAAAAAAAA****************
# + ultimo de chat gpt

# %% [markdown]
# 7. **Vectores.** Para trabajar con vectores en Python (y en general para todo tipo de operaciones
# matem´aticas) vamos a usar la bibliotece numpy. Para eso importamos primero numpy y definimos
# vectores con el comando np.array. Ejecutar el siguiente codigo y observar los resultados.

# %%
import numpy as np
v = np . array ([1 ,2 ,3])
w = np . array ([1.2 , 7 , np . pi ])
v , w , v + w

# %% [markdown]
# 8. La magia de Numpy La biblioteca Numpy reproduce muchas funcionalidades de Matlab. La
# mayor´ıa de las operaciones con vectores de Numpy se hacen coordenada a coordenada. Esto
# permite en muchos casos evitar usar ciclos o ciclos anidados y realizarlos con un solo comando.
# Ejecutar los siguientes comandos e interpretar los resultados.

# %%
np . set_printoptions ( precision =2 , suppress = True )
v = np . array ([1 ,2 , np .e ,7])
w = np . array ([1.2 , np . pi , 4 , 5])
print ("v+w = ", v + w )
print ("v*w = ", v * w )

# %% [markdown]
# Podemos probar varios comandos en un ciclo

# %%
for expr in ["v", "w", "v + w", "v ** 2", "v % 2", "np.sum(v)", "np. sqrt (w)", "v > 3", "w < 3.5 "
]:
  print ( f"{ expr :11s} == { eval ( expr )}")

# %% [markdown]
# 9. Bonus: descrifrar que hace la f-string que recibe como argumento print. ¿Y eso de eval?
# 10. Las operaciones logicas or y and no se pueden aplicar a vectores. Debemos usar los sımbolos |
# (or) y & (and).

# %%
( v > 3) | ( w < 3.5)
( v > 3) & ( w < 3.5)

# %% [markdown]
# 11. ¿Como se puede aplicar not a un vector de variables booleanas (x ∈ {True, False})? Pueden
# probar algunas ideas o buscar la respuesta en Internet.
# 12. Algunos comandos pueden dar resultados inesperados. Intenten adivinar cual va a ser el resultado de cada comando.

# %%
v = np . array ([1 ,2 , np .e ,7])
w = np . array ([1.2 , np . pi , 4 , 5])
z = np . array ([0 ,1])
v * w
v +2
v + z # Funcionara ?

# %% [markdown]
# 13. Explorar estas distintas formas de extraer informacion de un vector.

# %%
v = np . array ([1 , 2 , np .e , 7 , 5])
v [0] , v [1] , v [ -1] # funcionara ‘v[ -2] ‘?
v [[0 , 3]]
v [0:3] , v [0:1]

# %% [markdown]
# 14. Tambien podemos seleccionar los elementos que cumplan alguna propiedad.

# %%
v = np . array ([1 , 2 , np .e , 7 , 5])
w = np . array ([1 , 0 , 2 , 5 , 0])
v [ v > 2]
v [ w != 0]

# %% [markdown]
# 15. **Matrices** Las matrices se definen en numpy como arrays de filas. Las operaciones usuales
# se realizan coordenada a coordenada al igual que con vectores. Verificar los resultados de los
# siguientes comandos.

# %%
A = np . array ([[3 , 2 , 2] , [ -1 , 0 , 1] , [ -2 , 2 , 4]])
B = np . array ([[1 , 0 , 0] , [0 , 1 , 0] , [0 , 0 , 1]])
C = np . array ([[0 , 1 , -1] , [5 , -2 , 1]])
A + B
A * B
C **2 # bonus : pruebe con np

# %% [markdown]
# 16. El producto usual de matrices se realiza con el comando @. A.T es la transpuesta de A. Verificar
# los resultados de los siguientes comandos.

# %%
A @ B
B @ C
B . shape , C . shape
B @ C . T

# %% [markdown]
# **Funciones**
#
# Las funciones son bloques de codigo organizado que se usan para realizar tares especıficas.
# Reciben un input (un numero o una variable, por ejemplo) y devuelven un output. Los inputs van
# entre parentesis y separados por una coma, si hay mas de uno. Muchas funciones estan disponibles
# en la biblioteca estandar de Python, otras estas agrupadas en distintas bibliotecas, como numpy que
# agrupa una gran cantidad de funciones matematicas. El objetivo de estos ejercicios es familiarizarse
# con varias funciones basicas de Python.
#
# 17. Ejecutar estas operaciones para entender que hacen las funciones de numpy:

# %%
a = np . sqrt (2)
a
np . round ( a )
np . round (a , 2)
np . info ( np . round )
np . info ( np . ceil )

# %% [markdown]
# 18. Muchas funciones de numpy se pueden aplicar tambien en arrays:

# %%
v = np . array ([ a , a **2 , a **3 , a **(.5) ])
np . floor ( v )

# %% [markdown]
# 19. Explorar las funciones np.max(), np.min(), np.sum(), np.mean() y np.sort() aplicadas al vector
# v del ejercicio anterior. ¿Qu´e hace cada una?

# %% [markdown]
# 20. Definir los siguientes vectores como arrays de numpy:
# alturas cm = (180, 178, 154, 202),
# frutas = (”banana”, ”pera”, ”durazno”).
# ¿Cu´ales funciones del ejercicio anterior se pueden aplicar a cada uno de estos vectores? Verifiquen su respuesta.

# %% [markdown]
# 21. Utilizando solo las operaciones y funciones vistas en los ejercicios anteriores, escribir códigos de una sola línea para las siguientes funciones matemáticas.
#
# (a) $\|v\|_2 = \sqrt{v_1^2 + v_2^2 + \dots + v_n^2} = \sqrt{\sum_{i=1}^{n} v_i^2}$
#
# (b) $\|v - w\|_2$
#
# (c) $\langle v, w \rangle = v_1 \cdot w_1 + v_2 \cdot w_2 + \dots + v_n \cdot w_n = \sum_{i=1}^{n} v_i \cdot w_i$

# %% [markdown]
# 22. En Python podemos definir nuestras propias funciones utilizando def. ¿Que hace la siguiente
# funcion? ¿Que resultados esperan al aplicar la funcion a los vectores v0 y v1?

# %%
def todosPositivos ( v ) :
  return np .all ( v > 0)
v0 = np . array ([3 , 4])
v1 = np . array ([3 , 5 , -1 , 1])
for i , v in enumerate ([ v0 , v1 ]) :
  assert todosPositivos ( v ) , f
  "No todos los elementos son positivos en v{i}"

# %% [markdown]
# 23. Definir una funcion que calcule la norma-2 de un vector y verificarla en los vectores v0 y v1 del
# ejercicio anterior.

# %% [markdown]
# 24. Usar las funciones np.argmin() y np.argmax() con el vector de alturas definido anteriormente.
# Interpretar que hace cada una. Realizar otro experimento para comprobarlo.

# %% [markdown]
# 25. Reproducir estos usos de la funcion np.random.choice() e interpretar que hace.

# %%
x = np . array ([" cara ", " ceca "])
s = np . random . choice (x , size =10)
print ( s )
y = np . array ([1 ,2 ,3 ,4 ,5 ,6])
t = np . random . choice (y , size =10)
print ( t )
u = np . random . choice (y , size =4 , replace = False )
print ( u )

# %% [markdown]
# ¿Para que sirve el parametro replace=False? Realicen otras pruebas para verificarlo. Comparen con random.choices y random.sample de la biblioteca estandar de Python.

# %% [markdown]
# 26. **Ley de los grandes numeros**. Esta ley asegura que si tiramos n veces una moneda, la
# proporcion de veces que sale cara tiende a 1/2 cuando n tiende a infinito. Simular 10 lanzamientos de una moneda y calcular la proporcion de veces que sale cara. Repetir para n = 1000
# y n = 100.000.

# %% [markdown]
# 27. Se tira n veces una moneda. Intentar predecir, si existen, los siguientes lımites cuando n tiene
# a infinito y verificar la intuicion mediante simulaciones.
#
# (a) La cantidad de caras dividido por la cantidad de cecas.
#
# (b) La cantidad de caras menos la cantidad de cecas.
#
# (c) La cantidad de caras menos la cantidad de cecas, divido por la cantidad total de tiradas.
#
# (d) (difıcil) Considerando las veces que salieron tres caras seguidas, la proporcion de veces
# que en la siguiente tirada sale nuevamente cara.
